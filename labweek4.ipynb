# %%
# stacks -- LIFO

# %%
# LIFO: last in first out
push pop and peek
# Out:
#   File "/tmp/ipython-input-302111902.py", line 3
#     push pop and peek
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# 25
# 10 2 8
# (8 * 2) + 10
# then 3 - so minus 3

# %% [markdown]
# QUEUES -- FIRST IN FIRST OUT
#
# ex: restaurant reservations

# %% [markdown]
# q.append(x)
#  * add x to the end
# q.popleft()
#  * pop left instead of popping last, so return the first element
# q[0]
#  * peek
# len(q):
#
# if(q)
